# %%
import json
import os
import sys

# %% [markdown]
# ### Change 200k-live-face-dataset key paths

# %%
result_path = "/mnt/ssd/workspace/adi/repos/vh_deepfake_trainer/tools/dataset_assessor/result_200k_live_face_dataset.json"
with open(result_path, 'r') as f:
    # Parsing the JSON file into a Python dictionary
    data = json.load(f)

# %%
list(data.keys())[0]
# Out:
# '/mnt/ssd/datasets/deepfake/200k_live_face_dataset/processes/live/170203_verify_8b73353a-ea41-4820-a855-0035c2b4a5c5_d84a7070-fe9a-4c23-826c-134650e4783a_original.jpg.jpg'

# %%
data_new = {}

# %%
#Write dict to JSON
# Open the file in write mode ('w') and use json.dump() to write the dictionary
# Extract the directory path from the full file path  
directory = os.path.dirname(file_path)  
  
# Create the directory and any necessary parent directories if they don't exist  
# exist_ok=True prevents an error if the directory already exists  
if directory: # Only attempt to create if a directory path is provided  
	os.makedirs(directory, exist_ok=True)  

with open(file_path, 'w') as f:  
	json.dump(data, f, indent=4) # indent=4 makes the JSON output more readable
# Out:
# {'/mnt/ssd/datasets/deepfake/200k_live_face_dataset/processes/live/170203_verify_8b73353a-ea41-4820-a855-0035c2b4a5c5_d84a7070-fe9a-4c23-826c-134650e4783a_original.jpg.jpg': {'label': 0,
#   'method': 'production_live',
#   'processed_path': '/mnt/ssd/datasets/deepfake/200k_live_face_dataset/processes/live/face/170203_verify_8b73353a-ea41-4820-a855-0035c2b4a5c5_d84a7070-fe9a-4c23-826c-134650e4783a_original.jpg.jpg',
#   'landmarks_path': '/mnt/ssd/datasets/deepfake/200k_live_face_dataset/processes/live/landmarks/170203_verify_8b73353a-ea41-4820-a855-0035c2b4a5c5_d84a7070-fe9a-4c23-826c-134650e4783a_original.jpg_landmarks.npy',
#   'mask_path': '/mnt/ssd/datasets/deepfake/200k_live_face_dataset/processes/live/mask/170203_verify_8b73353a-ea41-4820-a855-0035c2b4a5c5_d84a7070-fe9a-4c23-826c-134650e4783a_original.jpg_mask.png',
#   'angle': 0,
#   'status': 'FACE DETECTED',
#   'pred_age': '10-19',
#   'score_blur_face': 64.37224850479575,
#   'score_dark': 6.042599850363189,
# ...
